# %% [markdown]
# # Import all necessary libraries

# %%
from datascience import *
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

import requests
import re
import numpy as np 
from numpy import argsort, searchsorted, array, size

import folium
import pandas as pd
from shapely.geometry import Point, Polygon

# %% [markdown]
# # Define a class 'tools' with convenient functions

# %%
class Tools:
    # Helper functions to trim whitespaces
    def trim_l(self, line):
        return re.sub(r'^\s+', '', line)

    def trim_r(self, line):
        return re.sub(r'\s+$', '', line)

    def trim(self, line):
        return self.trim_l(self.trim_r(line))

    # Check if the line is the start of a node
    def is_node_s(self, a):
        return re.match(r'^.*<node[\s+,>].*$', a, flags=re.IGNORECASE) is not None

    # Check if the line is the end of a node
    def is_node_e(self, a):
        return re.match(r'^.*</node>.*$', a, flags=re.IGNORECASE) is not None

    # Check if the line is the start of an element (way or relation)
    def is_elem_s(self, tag, a, flags=re.IGNORECASE):
        return re.match(r'^.*<' + str(tag) + '[\s+,>].*$', a, flags=flags) is not None

    # Check if the line is the end of an element (way or relation)
    def is_elem_e(self, tag, a, flags=re.IGNORECASE):
        return re.match(r'^.*</' + str(tag) + '>.*$', a, flags=flags) is not None

    # Extract node ID, latitude, and longitude from a line
    def getnode_id_lon_lat(self, line):
        xid = re.sub(r'^.*\s+id="([-+]?[0-9]*\.?[0-9]+([eE][-+]?[0-9]+)?)"\s+.*$', r'\1', line)
        xlon = re.sub(r'^.*\s+lon="([-+]?[0-9]*\.?[0-9]+([eE][-+]?[0-9]+)?)"\s+.*$', r'\1', line)
        xlat = re.sub(r'^.*\s+lat="([-+]?[0-9]*\.?[0-9]+([eE][-+]?[0-9]+)?)"\s+.*$', r'\1', line)
        return int(xid), float(xlat), float(xlon)

    # Extract ID from an element (node, way, relation)
    def getelem_id(self, line):
        xid = re.sub(r'^.*\s+id="([-+]?[0-9]*\.?[0-9]+([eE][-+]?[0-9]+)?)"\s+.*$', r'\1', line)
        return int(xid)

    # Extract tag data from a line
    def gettag_int(self, tag, line):
        xid = re.sub(r'^.*\s+' + str(tag) + '="([-+]?[0-9]*)"\s+.*$', r'\1', line)
        return int(xid)

    # Open and read the local file
    def get_osm(self, file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            Text = file.read().splitlines()  # Read all lines and split by newline

        # 1. To extract "node" information (id, lat, lon) and data (id_ref, tags)
        node_ref = []
        node_lon = []
        node_lat = []
        node_ref1 = []
        node_info = []

        nl = 0
        flag_s = flag_e = False
        xid = xlat = xlon = 0
        xdata = ''
        flag_open = False

        for line in Text:
            nl += 1
            flag_s = self.is_node_s(line)
            flag_e = self.is_node_e(line)
            if flag_s:
                flag_open = True
                xid, xlat, xlon = self.getnode_id_lon_lat(line)
                node_ref.append(xid)
                node_lat.append(xlat)
                node_lon.append(xlon)
                xdata = ''
            elif flag_e:
                flag_open = False
                node_ref1.append(xid)
                node_info.append(xdata)
            else:
                if flag_open:
                    xdata += str(self.trim(line))

        print(f"{1:4d} {'Reading Nodes over No. lines':40} {nl:15d}")
        print(f"{'No. Nodes =':45s} {len(node_ref):15d}")

        # 2. To extract "way" information (id) and way data (node_ref, tags, etc)
        way_ref = []
        way_info = []

        nl = 0
        flag_s = flag_e = False
        wid = 0
        wdata = ''
        flag_open = False

        for line in Text:
            nl += 1
            flag_s = self.is_elem_s('way', line)
            flag_e = self.is_elem_e('way', line)
            if flag_s:
                flag_open = True
                wid = self.getelem_id(line)
                way_ref.append(wid)
                wdata = ''
            elif flag_e:
                flag_open = False
                way_info.append(wdata)
            else:
                if flag_open:
                    wdata += str(self.trim(line))

        print(f"{2:4d} {'Reading Way over No. lines':40} {nl:15d}")
        print(f"{'No. Way =':45s} {len(way_ref):15d}")

        # 3. To extract "relation" information (id) and data (ref, tags, etc)
        rel_ref = []
        rel_info = []

        nl = 0
        flag_s = flag_e = False
        rid = 0
        rdata = ''
        flag_open = False

        for line in Text:
            nl += 1
            flag_s = self.is_elem_s('relation', line)
            flag_e = self.is_elem_e('relation', line)
            if flag_s:
                flag_open = True
                rid = self.getelem_id(line)
                rel_ref.append(rid)
                rdata = ''
            elif flag_e:
                flag_open = False
                rel_info.append(rdata)
            else:
                if flag_open:
                    rdata += str(self.trim(line))

        print(f"{3:4d} {'Reading Relation over No. lines':40} {nl:15d}")
        print(f"{'No. Relation =':45s} {len(rel_ref):15d}")

        return np.array(node_ref, dtype='int64'), \
               np.array(node_ref1, dtype='int64'), \
               np.array(way_ref, dtype='int64'), \
               np.array(rel_ref, dtype='int64'), \
               np.array(node_lon, dtype='float64'), \
               np.array(node_lat, dtype='float64'), \
               node_info, \
               way_info, \
               rel_info
    

    def extract_districts(self, rel_info):
        quan_lst = []
        quan_ref = []

        for k in range( len(rel_info) ):
            line = rel_info[k]
            if ( re.match( r'^.*Quận.*$', line, flags=re.IGNORECASE ) is not None ) :
                if ( re.match( r'^.*<tag k="name" v="Quận\s+.*$', line, flags=re.IGNORECASE ) is not None ) :
                    quan = re.sub( r'^.*(<tag k="name" v=")(Quận\s+(\d+|[A-Za-zÀ-ỹ\s]+))("/>.*)$', r'\2', line )
                    if ( quan is not None ):
                        quan_lst.append ( quan )
                        quan_ref.append ( k )
                
        return quan_lst, quan_ref
    
    
    
    # searching the table by ID
    def table_search(self, t, xid, col=0):
        if col == 0:
            k = searchsorted(t.column(col), xid)
            return t.take(k)        
        else:
            ia = argsort(t.column(col))
            k = searchsorted(t.column(col), xid, sorter=ia)
            return t.take(ia[k])

    # Get index from ref 
    def find_id_from_ref(self, aref, iref, getsorted=True):
        if getsorted:
            k = searchsorted(aref, iref)
        else:
            ia = argsort(aref)
            k = searchsorted(aref, iref, sorter=ia)
        return k

    
    def get_values_from_ref(self, aval, aref, iref):
        if size(iref) == 1:        
            iid = self.find_id_from_ref(np.dtype('int64').type(aref), iref, getsorted=True)
            return array(aval)[iid]
        else:
            list_id = [] 
            for j in range(size(iref)):
                list_id.append(self.find_id_from_ref(np.dtype('int64').type(aref), iref[j], getsorted=True))
            return array(aval)[list_id]
        
    def get_rel_from_ix(self, ref, rel_info):
        return rel_info[ref]
    
    
    # way

    # extract tag with key-value pair
    def way_has_tags(self, wval):
        tag_dict = {}
        for k, v in re.findall(r'<tag k="([^"]+)" v="([^"]+)"', wval):
            if k not in tag_dict:
                tag_dict[k] = v
            else:
                tag_dict[k].append(v)  
        return tag_dict 
    
    # extract all node refs
    def way_has_nodes(self, wval):
        nodes = []
        for x in re.findall(r'<nd\b(.*?)\/>', wval):
            nodes.append(self.trim(x))
        return nodes

    # convert all node refs to int and store in an array 
    def way_has_ref_of_node(self, wval):
        def get_ref(ele):
            k = re.sub(r'^ref="([-+]?[0-9]*\.?[0-9]+([eE][-+]?[0-9]+)?)"$', r'\1', ele)
            return np.dtype('int64').type(k)
        
        rnodes = []
        for x in self.way_has_nodes(wval):
            rnodes.append(get_ref(self.trim(x)))
        return np.dtype('int64').type(rnodes)
    
    # return node refs and tags pair 
    def way_has_refs_n_tags(self, wval):
        tag_dict = self.way_has_tags(wval)  
        return self.way_has_ref_of_node(wval), tag_dict
    
    # find ix of way from ref 
    def wayid_from_ref(self, wref):
        return self.find_id_from_ref(np.dtype('int64').type(way_ref), wref, getsorted=True)

    # extract info from ref 
    def wayinfo_from_ref(self, wref):
        return way_info[self.wayid_from_ref(wref)]
    
    
    
    # Input is relation infor 
    # return node refs , way refs, relation refs, tag with key-value pair
    def get_has_refs_n_tags(self, rquan):
        node_ref_pattern = r'<member type="node" ref="(\d+)"'
        way_ref_pattern = r'<member type="way" ref="(\d+)"'
        relation_ref_pattern = r'<member type="relation" ref="(\d+)"'
        tag_pattern = r'<tag k="([^"]+)" v="([^"]+)"'

        node_refs = list(map(int, re.findall(node_ref_pattern, rquan)))
        way_refs = list(map(int, re.findall(way_ref_pattern, rquan)))
        relation_refs = list(map(int, re.findall(relation_ref_pattern, rquan)))
        tags = re.findall(tag_pattern, rquan)

        tag_dict = {k: v for k, v in tags}

        return node_refs, way_refs, relation_refs, tag_dict
    
    # get coordinates(lat,lon) for all node refs input
    def get_coordinates_for_nodes(self, wn, node_ref, node_lat, node_lon):
        line_coordinates = []
        for r in wn:
            xlat = self.get_values_from_ref(node_lat, node_ref, r)
            xlon = self.get_values_from_ref(node_lon, node_ref, r)
            line_coordinates.append([xlat, xlon])
        return line_coordinates

    # input is all way refs in relation 
    def get_lines(self, qw, node_ref, node_lat, node_lon):
        qw_lines = [] 
        for j in range(len(qw)):
            wref = qw[j]
            wval = self.wayinfo_from_ref(wref)
            wn, _ = self.way_has_refs_n_tags(wval)
            line_coordinates = self.get_coordinates_for_nodes(wn, node_ref, node_lat, node_lon)
            qw_lines.append(line_coordinates)

        return qw_lines
    
    # this function ensures that all coordiantes continuous and closed polygon  
    def close_polygon(self, boundary_lines):
        blines = np.copy(np.array(boundary_lines[0]).reshape((-1, 2)))
        btail = blines[-1]  

        flags = np.zeros(len(boundary_lines))  
        flags[0] = 1  

        while np.count_nonzero(flags) < len(boundary_lines):
            hmin = 1.0e+10
            tmin = 1.0e+10
            ih = it = -1

            for n in range(1, len(boundary_lines)):
                if flags[n] > 0:
                    continue  

                xlines = np.copy(np.array(boundary_lines[n]).reshape((-1, 2)))
                xhead = xlines[0]  
                xtail = xlines[-1]  

                h1 = np.max(np.abs(xhead - btail))
                t1 = np.max(np.abs(xtail - btail))

                if h1 < hmin:
                    ih = n
                    hmin = h1

                if t1 < tmin:
                    it = n
                    tmin = t1

            if hmin < tmin:
                n = ih
                xlines = np.copy(np.array(boundary_lines[n]).reshape((-1, 2)))
                blines = np.append(blines, xlines, axis=0)
                btail = blines[-1]
            else:
                n = it
                xlines = np.copy(np.array(boundary_lines[n]).reshape((-1, 2)))
                blines = np.append(blines, xlines[::-1], axis=0) 
                btail = blines[-1]

            flags[n] = 1

        closed_polygon = np.append(blines, blines[0]).reshape((-1, 2))

        return closed_polygon
    
    
    # extract info in way info following tag_key and tag_value pair
    # return a table includes way ref, node refs and name of this way columns
    def extract_way_info(self, way_table, tag_key, tag_value):
    
        def parse_way_info(way_info, tag_key, tag_value):
            tag_pattern = rf'<tag k="{tag_key}" v="{tag_value}"/>'
            if re.search(tag_pattern, way_info):
                node_refs = [int(ref) for ref in re.findall(r'<nd ref="(\d+)"/>', way_info)]
                name = re.search(r'<tag k="name" v="([^"]+)"/>', way_info)
                name_value = name.group(1) if name else None
                return node_refs, name_value
            return None, None

        way_refs = way_table.column('ref')
        way_infos = way_table.column('info')

        filtered_data = []

        for ref, info in zip(way_refs, way_infos):
            node_refs, name = parse_way_info(info, tag_key, tag_value)
            if node_refs is not None:
                filtered_data.append((ref, node_refs, name))

        return Table().with_columns(
            'ref', [row[0] for row in filtered_data],
            'node_refs', [row[1] for row in filtered_data],
            'name', [row[2] for row in filtered_data]
        )
    
    
    # extract center point of a polygon
    def get_polygon_center(self, polygon_coords):
        polygon = Polygon(polygon_coords)
        centroid = polygon.centroid
        
        return (centroid.x, centroid.y)

# %% [markdown]
# tools = Tools()

# %% [markdown]
# ----
# # Read osm file to extract data
#
# ----

# %%
node_ref, node_ref1, way_ref, rel_ref,\
node_lon, node_lat, node_info, way_info, rel_info = tools.get_osm('data/data_district_7.osm')
# Out:
#    1 Reading Nodes over No. lines                      553471
# No. Nodes =                                            155096
#    2 Reading Way over No. lines                        553471
# No. Way =                                               29779
#    3 Reading Relation over No. lines                   553471
# No. Relation =                                            633

# %% [markdown]
# ----
# # Combine data into tables form and save them in CSV files
#
# ----

# %% [markdown]
# ### _t_node table (node_ref,  lat and lon )_

# %%
t_node = Table().with_columns(
    'ref', node_ref,
    'lat', node_lat,
    'lon', node_lon
).sort( 'ref' )

print ( t_node.num_rows  )

#save
df = t_node.to_df()
df.to_csv('data/t_node.csv', index=False)

t_node.show(3)
# Out:
# 155096
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ref</th> <th>lat</th> <th>lon</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>366367233</td> <td>10.7711</td> <td>106.71 </td>
#         </tr>
#         <tr>
#             <td>366367242</td> <td>10.7093</td> <td>106.737</td>
#         </tr>
#         <tr>
#             <td>366367408</td> <td>10.7495</td> <td>106.723</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (155093 rows omitted)</p>

# %% [markdown]
# ### _t_node_info table (node_info_ref,  info )_

# %%
t_node_info = Table().with_columns(
    'ref', node_ref1,
    'info', node_info
).sort( 'ref' )

print ( t_node_info.num_rows  )

#save
df = t_node_info.to_df()
df.to_csv('data/t_node_info.csv', index=False)

t_node_info.show(3)
# Out:
# 13374
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ref</th> <th>info</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>366370651</td> <td><tag k="crossing" v="uncontrolled"/><tag k="highway" v=" ...</td>
#         </tr>
#         <tr>
#             <td>366370764</td> <td><tag k="crossing" v="uncontrolled"/><tag k="highway" v=" ...</td>
#         </tr>
#         <tr>
#             <td>366374711</td> <td><tag k="crossing" v="uncontrolled"/><tag k="highway" v=" ...</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (13371 rows omitted)</p>

# %% [markdown]
# ### _t_way table (way_ref,  info )_

# %%
t_way = Table().with_columns(
    'ref', way_ref,
    'info', way_info
).sort( 'ref' )

print ( t_way.num_rows  )

#save
df = t_way.to_df()
df.to_csv('data/t_way.csv', index=False)

t_way.show(3)
# Out:
# 29779
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ref</th> <th>info</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>32575751</td> <td><nd ref="5738009490"/><nd ref="5738009489"/><nd ref="313 ...</td>
#         </tr>
#         <tr>
#             <td>32575869</td> <td><nd ref="366441747"/><nd ref="5738173336"/><nd ref="5738 ...</td>
#         </tr>
#         <tr>
#             <td>32575895</td> <td><nd ref="2304882882"/><nd ref="6772277928"/><nd ref="366 ...</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (29776 rows omitted)</p>

# %% [markdown]
# ### _t_rel table  (rel_ref,  info )_

# %%
t_rel = Table().with_columns(
    'ref', rel_ref,
    'info', rel_info
).sort( 'ref' )

print ( t_rel.num_rows  )

#save
df = t_rel.to_df()
df.to_csv('data/t_rel.csv', index=False)

t_rel.show(3)
# Out:
# 633
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ref</th> <th>info</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>49915  </td> <td><member type="relation" ref="3770621" role="subarea"/><t ...</td>
#         </tr>
#         <tr>
#             <td>1435294</td> <td><member type="way" ref="165295187" role="outer"/><member ...</td>
#         </tr>
#         <tr>
#             <td>1904421</td> <td><member type="way" ref="532477271" role="outer"/><member ...</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (630 rows omitted)</p>

# %% [markdown]
# ----
# # Read CSV files
#
# ----

# %%
node_table = Table.read_table('data/t_node.csv')
node_table
# Out:
# ref       | lat     | lon
# 366367233 | 10.7711 | 106.71
# 366367242 | 10.7093 | 106.737
# 366367408 | 10.7495 | 106.723
# 366367420 | 10.7404 | 106.686
# 366367523 | 10.762  | 106.675
# 366367541 | 10.7409 | 106.687
# 366367658 | 10.7514 | 106.679
# 366367908 | 10.7536 | 106.68
# 366368084 | 10.7435 | 106.714
# 366368291 | 10.7788 | 106.765
# ... (155086 rows omitted)

# %%
node_info_table = Table.read_table('data/t_node_info.csv')
node_info_table
# Out:
# ref       | info
# 366370651 | <tag k="crossing" v="uncontrolled"/><tag k="highway" v=" ...
# 366370764 | <tag k="crossing" v="uncontrolled"/><tag k="highway" v=" ...
# 366374711 | <tag k="crossing" v="uncontrolled"/><tag k="highway" v=" ...
# 366375698 | <tag k="crossing" v="uncontrolled"/><tag k="highway" v=" ...
# 366376465 | <tag k="crossing" v="uncontrolled"/><tag k="highway" v=" ...
# 366383255 | <tag k="crossing" v="uncontrolled"/><tag k="highway" v=" ...
# 366383451 | <tag k="crossing" v="traffic_signals"/><tag k="highway"  ...
# 366386678 | <tag k="crossing" v="uncontrolled"/><tag k="highway" v=" ...
# 366387791 | <tag k="crossing" v="uncontrolled"/><tag k="highway" v=" ...
# 366388361 | <tag k="highway" v="traffic_signals"/>
# ... (13364 rows omitted)

# %%
way_table = Table.read_table('data/t_way.csv')
way_table
# Out:
# ref      | info
# 32575751 | <nd ref="5738009490"/><nd ref="5738009489"/><nd ref="313 ...
# 32575869 | <nd ref="366441747"/><nd ref="5738173336"/><nd ref="5738 ...
# 32575895 | <nd ref="2304882882"/><nd ref="6772277928"/><nd ref="366 ...
# 32575935 | <nd ref="1894608446"/><nd ref="9480445654"/><nd ref="320 ...
# 32575985 | <nd ref="571360922"/><nd ref="6754150326"/><nd ref="6754 ...
# 32576047 | <nd ref="366423209"/><nd ref="12143003827"/><nd ref="881 ...
# 32576407 | <nd ref="5780672141"/><nd ref="366374203"/><nd ref="3663 ...
# 32576414 | <nd ref="1756272376"/><nd ref="5752816430"/><nd ref="268 ...
# 32576600 | <nd ref="366399988"/><nd ref="366383330"/><nd ref="57628 ...
# 32576644 | <nd ref="2685998285"/><nd ref="2685998289"/><tag k="high ...
# ... (29769 rows omitted)

# %%
relation_table = Table.read_table('data/t_rel.csv')
relation_table
# Out:
# ref     | info
# 49915   | <member type="relation" ref="3770621" role="subarea"/><t ...
# 1435294 | <member type="way" ref="165295187" role="outer"/><member ...
# 1904421 | <member type="way" ref="532477271" role="outer"/><member ...
# 1973756 | <member type="node" ref="369486734" role="admin_centre"/ ...
# 2204742 | <member type="way" ref="165491094" role="outer"/><member ...
# 2210236 | <member type="way" ref="377269912" role="outer"/><member ...
# 2531662 | <member type="way" ref="39514796" role="outer"/><tag k=" ...
# 2559086 | <member type="node" ref="10166265722" role="label"/><mem ...
# 2561415 | <member type="node" ref="10166265726" role="label"/><mem ...
# 2561568 | <member type="node" ref="10166265724" role="label"/><mem ...
# ... (623 rows omitted)

# %% [markdown]
# ### _Find all districts into dataset_

# %%
dist_list, dist_ix = tools.extract_districts(relation_table[1])

# %%
districts_table = Table().with_columns(
    'index', dist_ix,
    'District Name', dist_list
).sort( 'index' )

districts_table
# Out:
# index | District Name
# 14    | Quận 1
# 20    | Quận 7
# 31    | Quận 4
# 45    | Quận 3
# 46    | Quận 5
# 78    | Quận 10
# 83    | Quận 8

# %% [markdown]
# #### _My area is district 7 only_

# %%
district_7 = tools.table_search(districts_table, 20)
district_7
# Out:
# index | District Name
# 20    | Quận 7

# %% [markdown]
# ----
# # Data execution
#
# ----

# %% [markdown]
# ### Get relation of district 7

# %%
district_7_ix = district_7[0][0]

rel_district_7 = relation_table.take(district_7_ix)[1][0]

rel_district_7
# Out:
# '<member type="way" ref="205798561" role="outer"/><member type="way" ref="205958089" role="outer"/><member type="way" ref="205798559" role="outer"/><member type="way" ref="205798574" role="outer"/><member type="way" ref="532477270" role="outer"/><member type="way" ref="205798562" role="outer"/><member type="way" ref="289880833" role="outer"/><member type="way" ref="289941958" role="outer"/><member type="way" ref="205798563" role="outer"/><member type="way" ref="290064899" role="outer"/><member type="way" ref="192036001" role="outer"/><member type="way" ref="192036002" role="outer"/><member type="way" ref="205798560" role="outer"/><member type="way" ref="418085082" role="outer"/><member type="way" ref="205798578" role="outer"/><member type="way" ref="206677429" role="outer"/><member type="way" ref="205798579" role="outer"/><member type="way" ref="205798575" role="outer"/><member type="way" ref="206677437" role="outer"/><member type="way" ref="502262238" role="outer"/><member type="way" ref="502903913" role="outer"/><member type="way" ref="504152911" role="outer"/><member type="relation" ref="2766952" role="subarea"/><member type="relation" ref="2766954" role="subarea"/><member type="relation" ref="2766951" role="subarea"/><member type="relation" ref="2766950" role="subarea"/><member type="relation" ref="2766956" role="subarea"/><member type="relation" ref="2766947" role="subarea"/><member type="relation" ref="2766953" role="subarea"/><member type="relation" ref="2766948" role="subarea"/><member type="relation" ref="2766955" role="subarea"/><member type="relation" ref="2766949" role="subarea"/><member type="node" ref="11214914777" role="label"/><tag k="admin_level" v="6"/><tag k="boundary" v="administrative"/><tag k="name" v="Quận 7"/><tag k="name:en" v="District 7"/><tag k="name:fr" v="7e arrondissement"/><tag k="name:ko" v="7군"/><tag k="name:zh" v="第七郡"/><tag k="population" v="244276"/><tag k="type" v="boundary"/><tag k="wikidata" v="Q5283266"/>'

# %% [markdown]
# ## arrange data into relation of district 7

# %%
dist_n, dist_w, dist_r, dist_t = tools.get_has_refs_n_tags(rel_district_7)

# %% [markdown]
# ## Find and plot district 7's center point

# %% [markdown]
# #### find lat and lon of center point district 7

# %%
dist_n[0]
# Out:
# 11214914777

# %%
dist_lat = tools.get_values_from_ref( node_lat, node_ref, dist_n[0] ) 
dist_lon = tools.get_values_from_ref( node_lon, node_ref, dist_n[0] )  

map_center = [ dist_lat, dist_lon ]

print ( 'center point = ( %15.10f,  %15.10f )\t node reference = %d ' % ( dist_lat, dist_lon, dist_n[0] ) )
# Out:
# center point = (   10.7375481000,   106.7302238000 )	 node reference = 11214914777

# %% [markdown]
# #### plot this point on map

# %%
district = folium.Map ( location=map_center, zoom_start=13)

folium.Marker(
    location=map_center,
    tooltip="Click me!",
    popup="Center of district 7",
    icon=folium.Icon(color="purple"),
).add_to(district)

# district.save ( "data/images/center_of_district_7.html" )

district
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba53c948ce66100dfa1602ae94c08e98 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba53c948ce66100dfa1602ae94c08e98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba53c948ce66100dfa1602ae94c08e98 = L.map(
#                 &quot;map_ba53c948ce66100dfa1602ae94c08e98&quot;,
#                 {
#                     center: [10.7375481, 106.7302238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eaeb071d9647bb03f86d18ab8e3c265e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eaeb071d9647bb03f86d18ab8e3c265e.addTo(map_ba53c948ce66100dfa1602ae94c08e98);
#
#
#             var marker_5797f6fbeeb750a751246cf2ab2e02a7 = L.marker(
#                 [10.7375481, 106.7302238],
#                 {}
#             ).addTo(map_ba53c948ce66100dfa1602ae94c08e98);
#
#
#             var icon_392c0a058a8563d6ce555fdba9cc03b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5797f6fbeeb750a751246cf2ab2e02a7.setIcon(icon_392c0a058a8563d6ce555fdba9cc03b8);
#
#
#         var popup_870d63fbdbc6d4f6c040f060c1c49eab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8abab15522e479202c569845e5bfe7e4 = $(`&lt;div id=&quot;html_8abab15522e479202c569845e5bfe7e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center of district 7&lt;/div&gt;`)[0];
#                 popup_870d63fbdbc6d4f6c040f060c1c49eab.setContent(html_8abab15522e479202c569845e5bfe7e4);
#
#
#
#         marker_5797f6fbeeb750a751246cf2ab2e02a7.bindPopup(popup_870d63fbdbc6d4f6c040f060c1c49eab)
#         ;
#
#
#
#
#             marker_5797f6fbeeb750a751246cf2ab2e02a7.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## get district 7's boundary  and plot

# %% [markdown]
# #### _get boundary_

# %%
boundary_dist_7 = tools.close_polygon( tools.get_lines( dist_w, node_ref, node_lat, node_lon ) )

# %% [markdown]
# #### _plot on map with polygon line_

# %%
folium.Polygon(
    locations = boundary_dist_7,
    color = "blue", 
    weight=2        
).add_to(district)

# district.save ( "data/images/boundary_of_district_7.html" )


district
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba53c948ce66100dfa1602ae94c08e98 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba53c948ce66100dfa1602ae94c08e98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba53c948ce66100dfa1602ae94c08e98 = L.map(
#                 &quot;map_ba53c948ce66100dfa1602ae94c08e98&quot;,
#                 {
#                     center: [10.7375481, 106.7302238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eaeb071d9647bb03f86d18ab8e3c265e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eaeb071d9647bb03f86d18ab8e3c265e.addTo(map_ba53c948ce66100dfa1602ae94c08e98);
#
#
#             var marker_5797f6fbeeb750a751246cf2ab2e02a7 = L.marker(
#                 [10.7375481, 106.7302238],
#                 {}
#             ).addTo(map_ba53c948ce66100dfa1602ae94c08e98);
#
#
#             var icon_392c0a058a8563d6ce555fdba9cc03b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5797f6fbeeb750a751246cf2ab2e02a7.setIcon(icon_392c0a058a8563d6ce555fdba9cc03b8);
#
#
#         var popup_870d63fbdbc6d4f6c040f060c1c49eab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8abab15522e479202c569845e5bfe7e4 = $(`&lt;div id=&quot;html_8abab15522e479202c569845e5bfe7e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center of district 7&lt;/div&gt;`)[0];
#                 popup_870d63fbdbc6d4f6c040f060c1c49eab.setContent(html_8abab15522e479202c569845e5bfe7e4);
#
#
#
#         marker_5797f6fbeeb750a751246cf2ab2e02a7.bindPopup(popup_870d63fbdbc6d4f6c040f060c1c49eab)
#         ;
#
#
#
#
#             marker_5797f6fbeeb750a751246cf2ab2e02a7.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_eaeb071d9647bb03f86d18ab8e3c265e.addTo(map_ba53c948ce66100dfa1602ae94c08e98);
#
#
#             var polygon_1d77e5c625f564be2559544fabef306c = L.polygon(
#                 [[10.7431427, 106.7686561], [10.7440812, 106.7605662], [10.7440883, 106.7601692], [10.7440889, 106.7597722], [10.744083, 106.7593752], [10.7440706, 106.7589784], [10.7440515, 106.758578], [10.7440259, 106.7581781], [10.7439936, 106.7577786], [10.7439547, 106.7573798], [10.7438916, 106.7569444], [10.7438192, 106.7565106], [10.7437377, 106.7560784], [10.743647, 106.7556481], [10.7435471, 106.75522], [10.7434382, 106.7547941], [10.7433295, 106.7544029], [10.7432132, 106.754014], [10.7430893, 106.7536276], [10.7429578, 106.7532437], [10.7428188, 106.7528626], [10.7426724, 106.7524844], [10.7425185, 106.7521092], [10.7424353, 106.7518252], [10.7423611, 106.7515387], [10.7422959, 106.7512499], [10.7422397, 106.7509591], [10.7421927, 106.7506666], [10.7421549, 106.7503728], [10.7421263, 106.7500779], [10.7421069, 106.7497822], [10.7420969, 106.749486], [10.742096, 106.7491947], [10.7421041, 106.7489034], [10.7421212, 106.7486126], [10.7421472, 106.7483224], [10.7421822, 106.7480332], [10.742226, 106.7477453], [10.7422863, 106.7475629], [10.742354, 106.7473831], [10.7424288, 106.7472063], [10.7425107, 106.7470328], [10.7425995, 106.7468629], [10.7426951, 106.7466968], [10.7427973, 106.7465349], [10.7429059, 106.7463773], [10.7430337, 106.746208], [10.743169, 106.7460447], [10.7433115, 106.7458879], [10.7434608, 106.7457379], [10.7436167, 106.7455949], [10.7437788, 106.7454593], [10.7439468, 106.7453313], [10.7441616, 106.7451937], [10.7443801, 106.7450623], [10.7443801, 106.7450623], [10.7446022, 106.7449372], [10.7448276, 106.7448185], [10.7450562, 106.7447063], [10.7452881, 106.7446006], [10.7455228, 106.7445015], [10.7457601, 106.7444091], [10.7459999, 106.7443236], [10.746242, 106.744245], [10.7464701, 106.7441954], [10.7466999, 106.7441547], [10.7469311, 106.744123], [10.7471633, 106.7441003], [10.7473962, 106.7440867], [10.7476196, 106.7440823], [10.747843, 106.7440861], [10.7480661, 106.7440984], [10.7482886, 106.7441189], [10.7485103, 106.7441478], [10.7487307, 106.7441849], [10.7489496, 106.7442302], [10.7493188, 106.7443435], [10.7496854, 106.7444647], [10.7500495, 106.7445938], [10.7504108, 106.7447307], [10.7507692, 106.7448753], [10.7511183, 106.7450249], [10.7514643, 106.7451818], [10.751807, 106.745346], [10.7521463, 106.7455175], [10.752482, 106.7456961], [10.7528795, 106.7459293], [10.7532734, 106.7461688], [10.7536636, 106.7464144], [10.7540501, 106.7466661], [10.7544328, 106.7469237], [10.7548115, 106.7471874

# %% [markdown]
# ## Find all wards in district 7

# %%
ward_refs_in_dist_7 = dist_r
ward_ixs_in_dist_7 = [tools.find_id_from_ref(rel_ref, ref) for ref in ward_refs_in_dist_7]

ward_ns = []
ward_ws = []
ward_ts = []
ward_bounds = []

for ix in ward_ixs_in_dist_7:
    ward_rel = tools.get_rel_from_ix(ix, rel_info)
    ward_n, ward_w, _, ward_t = tools.get_has_refs_n_tags(ward_rel)
    ward_bound = tools.get_lines( ward_w, node_ref, node_lat, node_lon )
    ward_ns.append(ward_n[0])
    ward_ws.append(ward_w)
    ward_ts.append(ward_t['name'])
    ward_bounds.append(ward_bound)
    

wards_table = Table().with_columns(
    'index', ward_ixs_in_dist_7,
    'ward_ref', ward_refs_in_dist_7,
    'node_ref', ward_ns,
    'way_refs', ward_ws,
    'name', ward_ts,
    'boundary', ward_bounds
).sort('index')

# %%
wards_table
# Out:
# index | ward_ref | node_ref    | way_refs                                                     | name                  | boundary
# 21    | 2766947  | 10166760587 | [205958109, 205958091, 205958108, 205958106, 205958107]      | Phường Bình Thuận     | [[[10.7383735, 106.7159346], [10.7380265, 106.7216411999 ...
# 22    | 2766948  | 10166760588 | [205958090, 205798559, 205798574, 532477270, 289854278]      | Phường Phú Mỹ         | [[[10.7127242, 106.7512311], [10.7134383, 106.7431980000 ...
# 23    | 2766949  | 10166760596 | [205958090, 205958112, 205958088, 205798561, 205958089]      | Phường Phú Thuận      | [[[10.7127242, 106.7512311], [10.7134383, 106.7431980000 ...
# 24    | 2766950  | 10166760591 | [205958098, 205958123, 289941957, 205798563, 290064899,  ... | Phường Tân Hưng       | [[[10.7525084, 106.7050033], [10.7520931, 106.70499], [1 ...
# 25    | 2766951  | 10166760592 | [418085082, 205958098, 205958100, 205958108, 205958087,  ... | Phường Tân Kiểng      | [[[10.7525084, 106.7050033], [10.7524958, 106.7058182],  ...
# 26    | 2766952  | 10166760590 | [289880833, 205958105, 205958097, 289941957, 289941958]      | Phường Tân Phong      | [[[10.7223883, 106.7203751], [10.7222109, 106.7198944],  ...
# 27    | 2766953  | 10166760589 | [289854278, 205798562, 205958105, 260850606, 205958109,  ... | Phường Tân Phú        | [[[10.7176198, 106.7367933], [10.7177586, 106.7361504],  ...
# 28    | 2766954  | 10166760593 | [205958123, 205958100, 205958091, 260850606, 205958097]      | Phường Tân Quy        | [[[10.7449938, 106.7043422], [10.739906, 106.7035552]],  ...
# 29    | 2766955  | 10166760594 | [205958110, 205798579, 205958087, 205958106]                 | Phường Tân Thuận Tây  | [[[10.7495081, 106.72873920000001], [10.7533463, 106.728 ...
# 30    | 2766956  | 10166760595 | [205958088, 205958107, 205958110, 205798575, 206677437,  ... | Phường Tân Thuận Đông | [[[10.7375361, 106.7304317], [10.7378178, 106.7308426],  ...

# %% [markdown]
# ## Plot all wards on map with polygon lines

# %%
for i in range(wards_table.num_rows): 
    
    row_i = wards_table.take(i)
    
    ward_lat = tools.get_values_from_ref(node_lat, node_ref, row_i['node_ref'])
    ward_lon = tools.get_values_from_ref(node_lon, node_ref, row_i['node_ref'])

    ward_center = [ward_lat, ward_lon]


    folium.Marker(
        location=ward_center,
        tooltip="Click me!",
        popup= row_i['name'][0],  
        icon=folium.Icon( color="cadetblue"),
    ).add_to(district)
        
    ward_boundary = tools.close_polygon(row_i['boundary'][0])
    folium.Polygon(
        locations = ward_boundary,
        color = "blue", 
        weight=2        
    ).add_to(district)
    

# district.save ( "data/images/boundary_of_wards`(no_color)`.html" )
    

district
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba53c948ce66100dfa1602ae94c08e98 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba53c948ce66100dfa1602ae94c08e98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba53c948ce66100dfa1602ae94c08e98 = L.map(
#                 &quot;map_ba53c948ce66100dfa1602ae94c08e98&quot;,
#                 {
#                     center: [10.7375481, 106.7302238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eaeb071d9647bb03f86d18ab8e3c265e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eaeb071d9647bb03f86d18ab8e3c265e.addTo(map_ba53c948ce66100dfa1602ae94c08e98);
#
#
#             var marker_5797f6fbeeb750a751246cf2ab2e02a7 = L.marker(
#                 [10.7375481, 106.7302238],
#                 {}
#             ).addTo(map_ba53c948ce66100dfa1602ae94c08e98);
#
#
#             var icon_392c0a058a8563d6ce555fdba9cc03b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5797f6fbeeb750a751246cf2ab2e02a7.setIcon(icon_392c0a058a8563d6ce555fdba9cc03b8);
#
#
#         var popup_870d63fbdbc6d4f6c040f060c1c49eab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8abab15522e479202c569845e5bfe7e4 = $(`&lt;div id=&quot;html_8abab15522e479202c569845e5bfe7e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center of district 7&lt;/div&gt;`)[0];
#                 popup_870d63fbdbc6d4f6c040f060c1c49eab.setContent(html_8abab15522e479202c569845e5bfe7e4);
#
#
#
#         marker_5797f6fbeeb750a751246cf2ab2e02a7.bindPopup(popup_870d63fbdbc6d4f6c040f060c1c49eab)
#         ;
#
#
#
#
#             marker_5797f6fbeeb750a751246cf2ab2e02a7.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_eaeb071d9647bb03f86d18ab8e3c265e.addTo(map_ba53c948ce66100dfa1602ae94c08e98);
#
#
#             var polygon_1d77e5c625f564be2559544fabef306c = L.polygon(
#                 [[10.7431427, 106.7686561], [10.7440812, 106.7605662], [10.7440883, 106.7601692], [10.7440889, 106.7597722], [10.744083, 106.7593752], [10.7440706, 106.7589784], [10.7440515, 106.758578], [10.7440259, 106.7581781], [10.7439936, 106.7577786], [10.7439547, 106.7573798], [10.7438916, 106.7569444], [10.7438192, 106.7565106], [10.7437377, 106.7560784], [10.743647, 106.7556481], [10.7435471, 106.75522], [10.7434382, 106.7547941], [10.7433295, 106.7544029], [10.7432132, 106.754014], [10.7430893, 106.7536276], [10.7429578, 106.7532437], [10.7428188, 106.7528626], [10.7426724, 106.7524844], [10.7425185, 106.7521092], [10.7424353, 106.7518252], [10.7423611, 106.7515387], [10.7422959, 106.7512499], [10.7422397, 106.7509591], [10.7421927, 106.7506666], [10.7421549, 106.7503728], [10.7421263, 106.7500779], [10.7421069, 106.7497822], [10.7420969, 106.749486], [10.742096, 106.7491947], [10.7421041, 106.7489034], [10.7421212, 106.7486126], [10.7421472, 106.7483224], [10.7421822, 106.7480332], [10.742226, 106.7477453], [10.7422863, 106.7475629], [10.742354, 106.7473831], [10.7424288, 106.7472063], [10.7425107, 106.7470328], [10.7425995, 106.7468629], [10.7426951, 106.7466968], [10.7427973, 106.7465349], [10.7429059, 106.7463773], [10.7430337, 106.746208], [10.743169, 106.7460447], [10.7433115, 106.7458879], [10.7434608, 106.7457379], [10.7436167, 106.7455949], [10.7437788, 106.7454593], [10.7439468, 106.7453313], [10.7441616, 106.7451937], [10.7443801, 106.7450623], [10.7443801, 106.7450623], [10.7446022, 106.7449372], [10.7448276, 106.7448185], [10.7450562, 106.7447063], [10.7452881, 106.7446006], [10.7455228, 106.7445015], [10.7457601, 106.7444091], [10.7459999, 106.7443236], [10.746242, 106.744245], [10.7464701, 106.7441954], [10.7466999, 106.7441547], [10.7469311, 106.744123], [10.7471633, 106.7441003], [10.7473962, 106.7440867], [10.7476196, 106.7440823], [10.747843, 106.7440861], [10.7480661, 106.7440984], [10.7482886, 106.7441189], [10.7485103, 106.7441478], [10.7487307, 106.7441849], [10.7489496, 106.7442302], [10.7493188, 106.7443435], [10.7496854, 106.7444647], [10.7500495, 106.7445938], [10.7504108, 106.7447307], [10.7507692, 106.7448753], [10.7511183, 106.7450249], [10.7514643, 106.7451818], [10.751807, 106.745346], [10.7521463, 106.7455175], [10.752482, 106.7456961], [10.7528795, 106.7459293], [10.7532734, 106.7461688], [10.7536636, 106.7464144], [10.7540501, 106.7466661], [10.7544328, 106.7469237], [10.7548115, 106.7471874

# %% [markdown]
# ## Plot the wards' boundaries with a filled color

# %%
colors = [
    'lightgreen',   
    'red',  
    'green',       
    'pink',        
    'cadetblue',   
    'lightblue',   
    'blue',       
    'darkred',     
    'orange',      
    'beige'        
]

for i in range(wards_table.num_rows):
    row_i = wards_table.take(i)

    ward_lat = tools.get_values_from_ref(node_lat, node_ref, row_i['node_ref'])
    ward_lon = tools.get_values_from_ref(node_lon, node_ref, row_i['node_ref'])
    ward_center = [ward_lat, ward_lon]


    folium.Marker(
        location=ward_center,
        tooltip="Click me!",
        popup=row_i['name'][0],  
        icon=folium.Icon(icon="cloud", color = colors[i]),
    ).add_to(district)

    ward_boundary = wards_table['boundary'][i]

    folium.Polygon(
        locations=tools.close_polygon(ward_boundary),  
        color="blue", 
        weight=2,         
        fill=True,        
        fill_color = colors[i],  
        fill_opacity=0.9  
    ).add_to(district)
    
    
# district.save ( "data/images/boundary_of_wards`(with_color)`.html" )

district
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba53c948ce66100dfa1602ae94c08e98 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba53c948ce66100dfa1602ae94c08e98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba53c948ce66100dfa1602ae94c08e98 = L.map(
#                 &quot;map_ba53c948ce66100dfa1602ae94c08e98&quot;,
#                 {
#                     center: [10.7375481, 106.7302238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eaeb071d9647bb03f86d18ab8e3c265e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eaeb071d9647bb03f86d18ab8e3c265e.addTo(map_ba53c948ce66100dfa1602ae94c08e98);
#
#
#             var marker_5797f6fbeeb750a751246cf2ab2e02a7 = L.marker(
#                 [10.7375481, 106.7302238],
#                 {}
#             ).addTo(map_ba53c948ce66100dfa1602ae94c08e98);
#
#
#             var icon_392c0a058a8563d6ce555fdba9cc03b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5797f6fbeeb750a751246cf2ab2e02a7.setIcon(icon_392c0a058a8563d6ce555fdba9cc03b8);
#
#
#         var popup_870d63fbdbc6d4f6c040f060c1c49eab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8abab15522e479202c569845e5bfe7e4 = $(`&lt;div id=&quot;html_8abab15522e479202c569845e5bfe7e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center of district 7&lt;/div&gt;`)[0];
#                 popup_870d63fbdbc6d4f6c040f060c1c49eab.setContent(html_8abab15522e479202c569845e5bfe7e4);
#
#
#
#         marker_5797f6fbeeb750a751246cf2ab2e02a7.bindPopup(popup_870d63fbdbc6d4f6c040f060c1c49eab)
#         ;
#
#
#
#
#             marker_5797f6fbeeb750a751246cf2ab2e02a7.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_eaeb071d9647bb03f86d18ab8e3c265e.addTo(map_ba53c948ce66100dfa1602ae94c08e98);
#
#
#             var polygon_1d77e5c625f564be2559544fabef306c = L.polygon(
#                 [[10.7431427, 106.7686561], [10.7440812, 106.7605662], [10.7440883, 106.7601692], [10.7440889, 106.7597722], [10.744083, 106.7593752], [10.7440706, 106.7589784], [10.7440515, 106.758578], [10.7440259, 106.7581781], [10.7439936, 106.7577786], [10.7439547, 106.7573798], [10.7438916, 106.7569444], [10.7438192, 106.7565106], [10.7437377, 106.7560784], [10.743647, 106.7556481], [10.7435471, 106.75522], [10.7434382, 106.7547941], [10.7433295, 106.7544029], [10.7432132, 106.754014], [10.7430893, 106.7536276], [10.7429578, 106.7532437], [10.7428188, 106.7528626], [10.7426724, 106.7524844], [10.7425185, 106.7521092], [10.7424353, 106.7518252], [10.7423611, 106.7515387], [10.7422959, 106.7512499], [10.7422397, 106.7509591], [10.7421927, 106.7506666], [10.7421549, 106.7503728], [10.7421263, 106.7500779], [10.7421069, 106.7497822], [10.7420969, 106.749486], [10.742096, 106.7491947], [10.7421041, 106.7489034], [10.7421212, 106.7486126], [10.7421472, 106.7483224], [10.7421822, 106.7480332], [10.742226, 106.7477453], [10.7422863, 106.7475629], [10.742354, 106.7473831], [10.7424288, 106.7472063], [10.7425107, 106.7470328], [10.7425995, 106.7468629], [10.7426951, 106.7466968], [10.7427973, 106.7465349], [10.7429059, 106.7463773], [10.7430337, 106.746208], [10.743169, 106.7460447], [10.7433115, 106.7458879], [10.7434608, 106.7457379], [10.7436167, 106.7455949], [10.7437788, 106.7454593], [10.7439468, 106.7453313], [10.7441616, 106.7451937], [10.7443801, 106.7450623], [10.7443801, 106.7450623], [10.7446022, 106.7449372], [10.7448276, 106.7448185], [10.7450562, 106.7447063], [10.7452881, 106.7446006], [10.7455228, 106.7445015], [10.7457601, 106.7444091], [10.7459999, 106.7443236], [10.746242, 106.744245], [10.7464701, 106.7441954], [10.7466999, 106.7441547], [10.7469311, 106.744123], [10.7471633, 106.7441003], [10.7473962, 106.7440867], [10.7476196, 106.7440823], [10.747843, 106.7440861], [10.7480661, 106.7440984], [10.7482886, 106.7441189], [10.7485103, 106.7441478], [10.7487307, 106.7441849], [10.7489496, 106.7442302], [10.7493188, 106.7443435], [10.7496854, 106.7444647], [10.7500495, 106.7445938], [10.7504108, 106.7447307], [10.7507692, 106.7448753], [10.7511183, 106.7450249], [10.7514643, 106.7451818], [10.751807, 106.745346], [10.7521463, 106.7455175], [10.752482, 106.7456961], [10.7528795, 106.7459293], [10.7532734, 106.7461688], [10.7536636, 106.7464144], [10.7540501, 106.7466661], [10.7544328, 106.7469237], [10.7548115, 106.7471874

# %% [markdown]
# ## Create district7's boundary polygon

# %%
boundary_district_7_polygon = Polygon(boundary_dist_7)

# %% [markdown]
# # Extract all shcools and plot on map

# %% [markdown]
# ### _Create university table_

# %%
unis_table = tools.extract_way_info(way_table, "amenity", "university")
unis_table.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ref</th> <th>node_refs</th> <th>name</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>140703173</td> <td>[1541029340, 9947678197, 9947678199, 9947678198, 9947678 ...</td> <td>Trường Đại học Sư phạm TP.HCM                           </td>
#         </tr>
#         <tr>
#             <td>140703186</td> <td>[1541029452, 9947678127, 9947678126, 1541029494, 1541029 ...</td> <td>Trường Đại học Khoa học Tự nhiên - ĐHQG TP.HCM - Cơ sở 1</td>
#         </tr>
#         <tr>
#             <td>149904631</td> <td>[1628403135, 1628403136, 1628403134, 1628403133, 1628403 ...</td> <td>CĐ nghề GTVT đường thủy II                              </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (20 rows omitted)</p>

# %% [markdown]
# ### _Create a table that includes all schools except universities_

# %%
schools_table = tools.extract_way_info(way_table, "amenity", "school")
schools_table.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ref</th> <th>node_refs</th> <th>name</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>140703181</td> <td>[1541029611, 1541029607, 4623130693, 1541029604, 1541029 ...</td> <td>Trường THPT chuyên Lê Hồng Phong  </td>
#         </tr>
#         <tr>
#             <td>140703185</td> <td>[1541029266, 11989673568, 11989673567, 8642545378, 15410 ...</td> <td>Trường Trung học Thực hành Sài Gòn</td>
#         </tr>
#         <tr>
#             <td>149904632</td> <td>[1628403385, 1628403393, 1628403372, 1628403362, 1628403385]</td> <td>Trường Hàn Quốc HCMC Korean School</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (136 rows omitted)</p>

# %% [markdown]
# #### _combine 2 table into an array_

# %%
edu_table = [unis_table, schools_table]

# %% [markdown]
# ## Plot all of them on map

# %%
edu_map = folium.Map(location=map_center, zoom_start=13 )

colors = [
    'darkred',   
    'cadetblue'        
]
 
# darkred color is universities
# cadetblue color is others school


for i, table in enumerate(edu_table):
    color = colors[i]
    for i in range( table.num_rows ):
        boundary = tools.close_polygon(tools.get_lines( [table.row(i)[0]], node_ref, node_lat, node_lon ))
        if np.shape(boundary)[0] >= 4:
            name = table.row(i)[2]
            if name:
                boundary_center = tools.get_polygon_center(boundary)
                center_point = [boundary_center[0], boundary_center[1]]  
                if boundary_district_7_polygon.contains(Point(center_point)):
                    folium.Marker(
                        location=center_point,  
                        tooltip="Click me!",
                        popup= name,  
                        icon=folium.Icon(icon="cloud", color=color),
                    ).add_to(edu_map)

                    folium.Polygon(
                        locations=boundary,  
                        color="blue", 
                        weight=2,         
                        fill=True,        
                        fill_color = color,  
                        fill_opacity=0.7  
                    ).add_to(edu_map)

folium.Polygon(
    locations = boundary_dist_7,
    color = "blue", 
    weight=2        
).add_to(edu_map)

# edu_map.save ( "data/images/education.html" )


edu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0a59472f70a8c8668ded2ad0564bbc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0a59472f70a8c8668ded2ad0564bbc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0a59472f70a8c8668ded2ad0564bbc8 = L.map(
#                 &quot;map_d0a59472f70a8c8668ded2ad0564bbc8&quot;,
#                 {
#                     center: [10.7375481, 106.7302238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8b10f257dafdf698de218affeb7af2a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b8b10f257dafdf698de218affeb7af2a.addTo(map_d0a59472f70a8c8668ded2ad0564bbc8);
#
#
#             var marker_89ba0e6b4c7354776f1fcfbe5fa43ea5 = L.marker(
#                 [10.709599993917495, 106.744369652848],
#                 {}
#             ).addTo(map_d0a59472f70a8c8668ded2ad0564bbc8);
#
#
#             var icon_85035cee18980e8520e514366ddbf072 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_89ba0e6b4c7354776f1fcfbe5fa43ea5.setIcon(icon_85035cee18980e8520e514366ddbf072);
#
#
#         var popup_8decd1c090f4fe7753ba0b84ede7c905 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_43db0e15e30d93e08c16eeebfcf9225c = $(`&lt;div id=&quot;html_43db0e15e30d93e08c16eeebfcf9225c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CĐ nghề GTVT đường thủy II&lt;/div&gt;`)[0];
#                 popup_8decd1c090f4fe7753ba0b84ede7c905.setContent(html_43db0e15e30d93e08c16eeebfcf9225c);
#
#
#
#         marker_89ba0e6b4c7354776f1fcfbe5fa43ea5.bindPopup(popup_8decd1c090f4fe7753ba0b84ede7c905)
#         ;
#
#
#
#
#             marker_89ba0e6b4c7354776f1fcfbe5fa43ea5.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var polygon_a00acaa91cbbdcd36ec7cc4a74f1f5ee = L.polygon(
#                 [[10.710048, 106.7435], [10.71007, 106.743713], [10.710017, 106.744934], [10.70988, 106.745209], [10.7093, 106.745354], [10.709147, 106.74511], [10.709189, 106.743584], [10.7096453, 106.743454], [10.710048, 106.7435], [10.710048, 106.7435]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_d0a59472f70a8c8668ded2ad0564bbc8);
#
#
#             var marker_e758337f858b71b61f83b48d46deba1b = L.marker(
#                 [10.729587925947998, 106.69360369445137],
#                 {}
#             ).addTo(map_d0a59472f70a8c8668ded2ad0564bbc8);
#
#
#             var icon_b1af8caf1c60b9dee2dce2a9d802ba94 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e758337f858b71b61f83b48d46deba1b.setIcon(icon_b1af8caf1c60b9dee2dce2a9d802ba94);
#
#
#         var popup_58086ff806a561e6304ae8a43df64492 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0dbe9e4ed67d64a61c5ec9793135829c = $(`&lt;div id=&quot;html_0dbe9e4ed67d64a61c5ec9793135829c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trường Đại Học RMIT Việt Nam&lt;/div&gt;`)[0];
#                 popup_58086ff806a561e6304ae8a43df64492.setContent(html_0dbe9e4ed67d64a61c5ec9793135829c);
#
#
#
#         marker_e758337f858b71b61f83b48d46deba1b.bindPopup(popup_58086ff806a561e6304ae8a43df64492)
#         ;
#
#
#
#
#             marker_e758337f858b71b61f83b48d46deba1b.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var polygon_9edcb287a7338209449b483fbb217d99 = L.polygon(
#                 [[10.7290504, 106.6909474], [10.729303, 106.6909571], [10.730104, 106.6910093], [10.7302193, 106.6910512], [10.7303307, 106.6911093], [10.7303968, 106.69115

# %% [markdown]
# ## Extract some of places

# %% [markdown]
# ### _hospital table_

# %%
hel_table = tools.extract_way_info(way_table, "amenity", "hospital")
hel_table.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ref</th> <th>node_refs</th> <th>name</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>158708608</td> <td>[1708640387, 2322640528, 1708640373, 10761763039, 170864 ...</td> <td>Bệnh Viện Pháp Việt      </td>
#         </tr>
#         <tr>
#             <td>158971987</td> <td>[1710814099, 3663992202, 1710814096, 10777654810, 170864 ...</td> <td>Bệnh Viện Tim Tâm Đức    </td>
#         </tr>
#         <tr>
#             <td>187949834</td> <td>[1985832561, 7503285427, 7503285426, 1985832668, 1985832 ...</td> <td>Bệnh viện Đa khoa Sài Gòn</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (20 rows omitted)</p>

# %% [markdown]
# ### _park table_

# %%
park_table = tools.extract_way_info(way_table, "leisure", "park")
park_table.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ref</th> <th>node_refs</th> <th>name</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>32735084 </td> <td>[2956813610, 2956817445, 368339701]                         </td> <td>Khu du lịch Kỳ Hòa      </td>
#         </tr>
#         <tr>
#             <td>149904638</td> <td>[1628403155, 1628403154, 1628403144, 1628403145, 1628403155]</td> <td>Trung Tâm Văn Hóa Quận 7</td>
#         </tr>
#         <tr>
#             <td>165271483</td> <td>[1768268752, 1768268750, 1768268751, 1768268742, 1768268 ...</td> <td>None                    </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (194 rows omitted)</p>

# %% [markdown]
# ### _golf table_

# %%
golf_table = tools.extract_way_info(way_table, "leisure", "golf_course")
golf_table.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ref</th> <th>node_refs</th> <th>name</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>158710364</td> <td>[1708656421, 5372370418, 367321853, 367321856, 367321862 ...</td> <td>Golf Nam Sai Gon</td>
#         </tr>
#         <tr>
#             <td>210778858</td> <td>[2208325312, 10776290609, 10776290608, 1756318867, 22083 ...</td> <td>Golf Nam Sai Gon</td>
#         </tr>
#         <tr>
#             <td>218448425</td> <td>[2276969190, 2276969189, 2276969185, 2276969177, 2276969 ...</td> <td>Sân Tập Golf    </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ### _supermarket table_

# %%
supermarket_table = tools.extract_way_info(way_table, "shop", "supermarket")
supermarket_table.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ref</th> <th>node_refs</th> <th>name</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>152994798</td> <td>[1657536332, 1657536313, 1657536318, 1657536311, 1657536 ...</td> <td>Co.op Mart Cống Quỳnh       </td>
#         </tr>
#         <tr>
#             <td>290188110</td> <td>[2937460934, 2937460935, 2937460936, 2937460937, 2937460 ...</td> <td>Citimart                    </td>
#         </tr>
#         <tr>
#             <td>509015321</td> <td>[4983065216, 4983065217, 4983065218, 4983065219, 4983065 ...</td> <td>Vinmart (Maximark) 3 tháng 2</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (3 rows omitted)</p>

# %% [markdown]
# ### _police table_

# %%
police_table = tools.extract_way_info(way_table, "amenity", "police")
police_table.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ref</th> <th>node_refs</th> <th>name</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>149904630</td> <td>[1628403149, 1628403146, 1628403141, 1628403142, 1628403 ...</td> <td>Công An Quận 7   </td>
#         </tr>
#         <tr>
#             <td>187895192</td> <td>[1985346271, 1985346092, 1985346153, 4611410090, 1985346 ...</td> <td>Sở Công An TP.HCM</td>
#         </tr>
#         <tr>
#             <td>224449760</td> <td>[2332723074, 2332723071, 2332723070, 2332723072, 2332723074]</td> <td>None             </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (12 rows omitted)</p>

# %% [markdown]
# ### _marketplace table_

# %%
marketplace_table = tools.extract_way_info(way_table, "amenity", "marketplace")
marketplace_table.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ref</th> <th>node_refs</th> <th>name</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>39514795 </td> <td>[473382796, 2893838361, 2893838357, 2893838358, 23535415 ...</td> <td>Chợ Bến Thành    </td>
#         </tr>
#         <tr>
#             <td>79345731 </td> <td>[926558653, 1777244267, 1777244405, 926558632, 177724438 ...</td> <td>Chợ Xóm Chiếu    </td>
#         </tr>
#         <tr>
#             <td>152992729</td> <td>[1657501021, 1657501019, 1657501017, 1657501025, 4613361 ...</td> <td>Chợ hoa Hồ Thị Kỷ</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (17 rows omitted)</p>

# %% [markdown]
# #### _combine all tables into an array_

# %%
others_table = [hel_table, park_table, golf_table, supermarket_table, police_table, marketplace_table]

# %% [markdown]
# ### Plot all of them on map

# %%
others_map = folium.Map(location=map_center, zoom_start=13 )

colors = [
    'lightgreen',   
    'red',  
    'green',       
    'pink',        
    'blue',       
    'beige'        
]
 
# lightgreen color is hospitals
# red color is parks
# green color is golfs 
# pink color  is supermaker 
# blue color is police stations
# beige color is marketplace 



for i, table in enumerate(others_table):
    color = colors[i]
    for i in range( table.num_rows ):
        boundary = tools.close_polygon(tools.get_lines( [table.row(i)[0]], node_ref, node_lat, node_lon ))
        if np.shape(boundary)[0] >= 4:
            name = table.row(i)[2]
            if name:
                boundary_center = tools.get_polygon_center(boundary)
                center_point = [boundary_center[0], boundary_center[1]]  
                if boundary_district_7_polygon.contains(Point(center_point)):
                    folium.Marker(
                        location=center_point,  
                        tooltip="Click me!",
                        popup= name,  
                        icon=folium.Icon(color=color),
                    ).add_to(others_map)

                    folium.Polygon(
                        locations=boundary,  
                        color="blue", 
                        weight=2,         
                        fill=True,        
                        fill_color = color,  
                        fill_opacity=0.7  
                    ).add_to(others_map)

folium.Polygon(
    locations = boundary_dist_7,
    color = "blue", 
    weight=2        
).add_to(others_map)

# others_map.save ( "data/images/amenities.html" )


others_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4c19396c61b52db78ec0c62f59e616d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4c19396c61b52db78ec0c62f59e616d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4c19396c61b52db78ec0c62f59e616d = L.map(
#                 &quot;map_c4c19396c61b52db78ec0c62f59e616d&quot;,
#                 {
#                     center: [10.7375481, 106.7302238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39874dbeb6af7327afc80877762df0c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_39874dbeb6af7327afc80877762df0c5.addTo(map_c4c19396c61b52db78ec0c62f59e616d);
#
#
#             var marker_f13eef702d5159f22962f202183042a1 = L.marker(
#                 [10.732444687338434, 106.71792568601663],
#                 {}
#             ).addTo(map_c4c19396c61b52db78ec0c62f59e616d);
#
#
#             var icon_3dbebc3e0e0d3d84995fe95e28415252 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f13eef702d5159f22962f202183042a1.setIcon(icon_3dbebc3e0e0d3d84995fe95e28415252);
#
#
#         var popup_76e06f82a901104c7045121b4e2d4a3b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_80c6b7cb5cc41da08d01439a750c358d = $(`&lt;div id=&quot;html_80c6b7cb5cc41da08d01439a750c358d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bệnh Viện Pháp Việt&lt;/div&gt;`)[0];
#                 popup_76e06f82a901104c7045121b4e2d4a3b.setContent(html_80c6b7cb5cc41da08d01439a750c358d);
#
#
#
#         marker_f13eef702d5159f22962f202183042a1.bindPopup(popup_76e06f82a901104c7045121b4e2d4a3b)
#         ;
#
#
#
#
#             marker_f13eef702d5159f22962f202183042a1.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var polygon_fd445153d690a889a2a9d8b95c05f73d = L.polygon(
#                 [[10.7331942, 106.7187921], [10.7328569, 106.7175567], [10.7326267, 106.7167135], [10.7322973, 106.7169172], [10.7315335, 106.7173895], [10.7325702, 106.7191642], [10.7331942, 106.7187921], [10.7331942, 106.7187921]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightgreen&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c4c19396c61b52db78ec0c62f59e616d);
#
#
#             var marker_1edc233511a5b565e3c14eb16cde4669 = L.marker(
#                 [10.733471522622834, 106.71781157263138],
#                 {}
#             ).addTo(map_c4c19396c61b52db78ec0c62f59e616d);
#
#
#             var icon_ec6fcf3686613f1e0fe8309305172bb8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1edc233511a5b565e3c14eb16cde4669.setIcon(icon_ec6fcf3686613f1e0fe8309305172bb8);
#
#
#         var popup_ee2a4e6212d19ade0123455dd102a348 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87cc9fb4806e8bfd4aae682265b968e9 = $(`&lt;div id=&quot;html_87cc9fb4806e8bfd4aae682265b968e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bệnh Viện Tim Tâm Đức&lt;/div&gt;`)[0];
#                 popup_ee2a4e6212d19ade0123455dd102a348.setContent(html_87cc9fb4806e8bfd4aae682265b968e9);
#
#
#
#         marker_1edc233511a5b565e3c14eb16cde4669.bindPopup(popup_ee2a4e6212d19ade0123455dd102a348)
#         ;
#
#
#
#
#             marker_1edc233511a5b565e3c14eb16cde4669.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var polygon_6e45bbcea264264be829b021d7be933e = L.polygon(
#                 [[10.7338563, 106.7177822], [10.7338047, 106.7183384], [10.7337707, 106.7184146], [10.7335247, 106.7185757], [10.7331942, 106.7187921], [10.7328569, 106.7175567], [10.7341229,

# %% [markdown]
# ![benign](data)

# %%
# !ls data/images/amenities.html
# Out:
# amenities.html                      boundary_of_wards (with_color).html
# boundary_of_district_7.html         center_of_district_7.html
# boundary_of_wards (no_color).html   education.html
